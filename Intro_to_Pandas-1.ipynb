# %% [markdown]
# # Introduction to Pandas Library Part-1

# %% [markdown]
# ## 1. Basic Concepts
#
# #### Pandas is a column oriented data analysis API. It's a great tool for handling and analyzing input data, and many ML frameworks support pandas data structures as inputs.
# #### There primary data structures in pandas are:
# #### - DataFrame, which is nothing but a relational table consisting of rows and columns
# #### - Series, which is a single column. So, a DataFrame is basically made up of many series

# %%
import pandas as pd
pd.__version__
# Out:
# '0.21.0'

# %%
# creating series object
names = pd.Series(['Sam','Bill','John'])
names
# Out:
# 0     Sam
# 1    Bill
# 2    John
# dtype: object

# %%
# creating DataFrame object by passing a dictionary 
age = pd.Series([12,26,40])
df = pd.DataFrame({'Name':names, 'Age':age})
df
# Out:
#    Age  Name
# 0   12   Sam
# 1   26  Bill
# 2   40  John

# %%
california_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")
california_df.head()  # by default returns 5 records
# california_df.head(20) returns first 20 records
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
california_df.tail() # returns the bottom records
california_df.tail(10)
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 41.73       -124.22                28.0       3003.0           699.0
# 41.75       -124.23                11.0       3159.0           616.0
# 40.81       -124.23                52.0       1112.0           209.0
# 40.54       -124.23                52.0       2694.0           453.0
# 40.28       -124.25                32.0       1430.0           419.0
# 40.58       -124.26                52.0       2217.0           394.0
# 40.69       -124.27                36.0       2349.0           528.0
# 41.84       -124.30                17.0       2677.0           531.0
# 41.80       -124.30                19.0       2672.0           552.0
# 40.54       -124.35                52.0       1820.0           300.0
#
#           population  households  median_income  median_house_value
# latitude
# 41.73         1530.0       653.0         1.7038             78300.0
# 41.75         1343.0       479.0         2.4805            100000.0
# 40.81          544.0       172.0         3.3462             50800.0
# 40.54         1152.0       435.0         3.0806            100000.0
# 40.28          434.0       187.0         1.9417             76100.0
# 40.58          907.0       369.0         2.3571            111400.0
# 40.69         1194.0       465.0         2.5179            100000.0
# 41.84         1244.0       456.0         3.0313            100000.0
# 41.80         1298.0       478.0         1.9797             85800.0
# 40.54          806.0       270.0         3.0147             94600.0

# %%
# getting the data types of all columns
california_df.dtypes
# Out:
# longitude             float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#getting the column names
california_df.columns
# Out:
# Index(['longitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value'],
#       dtype='object')

# %%
#tranposing your data
california_df.T
# Out:
# latitude                 34.19     34.40       33.69       33.64      33.57  \
# longitude            -114.3100   -114.47   -114.5600   -114.5700   -114.570
# housing_median_age     15.0000     19.00     17.0000     14.0000     20.000
# total_rooms          5612.0000   7650.00    720.0000   1501.0000   1454.000
# total_bedrooms       1283.0000   1901.00    174.0000    337.0000    326.000
# population           1015.0000   1129.00    333.0000    515.0000    624.000
# households            472.0000    463.00    117.0000    226.0000    262.000
# median_income           1.4936      1.82      1.6509      3.1917      1.925
# median_house_value  66900.0000  80100.00  85700.0000  73400.0000  65500.000
#
# latitude                 33.63        33.61       34.83        33.61  \
# longitude            -114.5800    -114.5800   -114.5900    -114.5900
# housing_median_age     29.0000      25.0000     41.0000      34.0000
# total_rooms          1387.0000    2907.0000    812.0000    4789.0000
# total_bedrooms        236.0000     680.0000    168.0000    1175.0000
# population            671.0000    1841.0000    375.0000    3134.0000
# households            239.0000     633.0000    158.0000    1056.0000
# median_income           3.3438       2.6768      1.7083       2.1782
# median_house_value  74000.0000  100000.0000  48500.0000  100000.0000
#
# latitude                 34.83     ...           41.73        41.75  \
# longitude            -114.6000     ...       -124.2200    -124.2300
# housing_median_age     46.0000     ...         28.0000      11.0000
# total_rooms          1497.0000     ...       3003.0000    3159.0000
# total_bedrooms        309.0000     ...        699.0000     616.0000
# population            787.0000     ...       1530.0000    1343.0000
# households            271.0000     ...        653.0000     479.0000
# median_income           2.1908     ...          1.7038       2.4805
# median_house_value  48100.0000     ...      78300.0000  100000.0000
#
# latitude                 40.81        40.54       40.28        40.58  \
# longitude            -124.2300    -124.2300   -124.2500    -124.2600
# housing_median_age     52.0000      52.0000     32.0000      52.0000
# total_rooms          1112.0000    2694.0000   1430.0000    2217.0000
# total_bedrooms        209.0000     453.0000    419.0000     394.0000
# population            544.0000    1152.0000    434.0000     907.0000
# households            172.0000     435.0000    187.0000     369.0000
# median_income           3.3462       3.0806      1.9417       2.3571
# median_house_value  50800.0000  100000.0000  76100.0000  111400.0000
#
# latitude                  40.69        41.84       41.80       40.54
# longitude             -124.2700    -124.3000   -124.3000   -124.3500
# housing_median_age      36.0000      17.0000     19.0000     52.0000
# total_rooms           2349.0000    2677.0000   2672.0000   1820.0000
# total_bedrooms         528.0000     531.0000    552.0000    300.0000
# population            1194.0000    1244.0000   1298.0000    806.0000
# households             465.0000     456.0000    478.0000    270.0000
# median_income            2.5179       3.0313      1.9797      3.0147
# median_house_value  100000.0000  100000.0000  85800.0000  94600.0000
#
# [8 rows x 17000 columns]

# %%
# sorting values by a particular column
california_df.sort_values(by='median_house_value').head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.14           0.0                 0.0          0.0             0.0
# 34.00           0.0                 0.0          0.0             0.0
# 34.17           0.0                 0.0          0.0             0.0
# 36.75           0.0                 0.0          0.0             0.0
# 39.51           0.0                 0.0          0.0             0.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.14            0.0         0.0            0.0                 0.0
# 34.00            0.0         0.0            0.0                 0.0
# 34.17            0.0         0.0            0.0                 0.0
# 36.75            0.0         0.0            0.0                 0.0
# 39.51            0.0         0.0            0.0                 0.0

# %%
california_df.describe()  # generates interesting statistics about the dataframe such as shape, dispersion. This will only display numeric columns

# california_df.describe(include='all') to describe all type of columns
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# ## 2. Accessing/ Indexing Data

# %%
california_df['latitude']
# california_df.latitude ; alternate way to access any single column data
california_df['latitude'][:5] #indexing similar to python lists
# Out:
# 0    34.19
# 1    34.40
# 2    33.69
# 3    33.64
# 4    33.57
# Name: latitude, dtype: float64

# %%
california_df[['latitude', 'longitude']]  # to access more than one column you can pass a list of column names
california_df[['latitude', 'longitude']].head(10)
# Out:
#    latitude  longitude
# 0     34.19    -114.31
# 1     34.40    -114.47
# 2     33.69    -114.56
# 3     33.64    -114.57
# 4     33.57    -114.57
# 5     33.63    -114.58
# 6     33.61    -114.58
# 7     34.83    -114.59
# 8     33.61    -114.59
# 9     34.83    -114.60

# %% [markdown]
# ### loc Method

# %%
''' Using loc for selecting rows by labels/index
we need to set an index column to access the rows if not set'''
california_df.set_index('latitude', inplace=True)  # inplace - Modify the DataFrame in place
california_df.head(5) # now we can easily access the rows using latitude values
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.40       -114.47                19.0       7650.0          1901.0
# 33.69       -114.56                17.0        720.0           174.0
# 33.64       -114.57                14.0       1501.0           337.0
# 33.57       -114.57                20.0       1454.0           326.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.19         1015.0       472.0         1.4936             66900.0
# 34.40         1129.0       463.0         1.8200             80100.0
# 33.69          333.0       117.0         1.6509             85700.0
# 33.64          515.0       226.0         3.1917             73400.0
# 33.57          624.0       262.0         1.9250             65500.0

# %%
california_df.loc[34.19].head()  #locating all rows with specific latitude value
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.19       -116.88                38.0        898.0           259.0
# 34.19       -117.32                 6.0       1068.0           182.0
# 34.19       -118.11                50.0       1430.0           186.0
# 34.19       -118.12                52.0       2405.0           299.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.19         1015.0       472.0         1.4936             66900.0
# 34.19          106.0        52.0         1.6875            225000.0
# 34.19          999.0       188.0         4.7222            109000.0
# 34.19          620.0       201.0         9.5320            483300.0
# 34.19          970.0       319.0         8.7835            444100.0

# %%
#locating rows with multiple latitude values by passing a list ; returns a dataframe
california_df.loc[[34.19, 34.40]].head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.19       -116.88                38.0        898.0           259.0
# 34.19       -117.32                 6.0       1068.0           182.0
# 34.19       -118.11                50.0       1430.0           186.0
# 34.19       -118.12                52.0       2405.0           299.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.19         1015.0       472.0         1.4936             66900.0
# 34.19          106.0        52.0         1.6875            225000.0
# 34.19          999.0       188.0         4.7222            109000.0
# 34.19          620.0       201.0         9.5320            483300.0
# 34.19          970.0       319.0         8.7835            444100.0

# %%
# selecting specific columns using specific index values
california_df.loc[[34.19, 34.40], ['longitude','housing_median_age','total_rooms']].head()
# Out:
#           longitude  housing_median_age  total_rooms
# latitude
# 34.19       -114.31                15.0       5612.0
# 34.19       -116.88                38.0        898.0
# 34.19       -117.32                 6.0       1068.0
# 34.19       -118.11                50.0       1430.0
# 34.19       -118.12                52.0       2405.0

# %%
# selecting  all columns between 'longitude':'total_rooms' using specific index values
california_df.loc[[34.19, 34.40], 'longitude':'total_rooms'].head()

# %% [markdown]
# ### iloc Method

# %%
'''Using boolean logic / conditinal statements for selecting rows using loc'''
# california_df.columns
california_df.loc[california_df.population > 500].head() #selecting all columns
# selecting specific columns
california_df.loc[california_df.population > 500, 'longitude':'households'].head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.40       -114.47                19.0       7650.0          1901.0
# 33.64       -114.57                14.0       1501.0           337.0
# 33.57       -114.57                20.0       1454.0           326.0
# 33.63       -114.58                29.0       1387.0           236.0
#
#           population  households
# latitude
# 34.19         1015.0       472.0
# 34.40         1129.0       463.0
# 33.64          515.0       226.0
# 33.57          624.0       262.0
# 33.63          671.0       239.0

# %%
# using lambda
california_df.loc[lambda california_df:california_df['population']>100].head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.40       -114.47                19.0       7650.0          1901.0
# 33.69       -114.56                17.0        720.0           174.0
# 33.64       -114.57                14.0       1501.0           337.0
# 33.57       -114.57                20.0       1454.0           326.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.19         1015.0       472.0         1.4936             66900.0
# 34.40         1129.0       463.0         1.8200             80100.0
# 33.69          333.0       117.0         1.6509             85700.0
# 33.64          515.0       226.0         3.1917             73400.0
# 33.57          624.0       262.0         1.9250             65500.0

# %%
# selecting a range values
california_df.loc[(california_df['population']>500) & (california_df['population']<1000) ].head()

# alternatively
california_df.loc[california_df['population'].between(500,1000) ].head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 33.64       -114.57                14.0       1501.0           337.0
# 33.57       -114.57                20.0       1454.0           326.0
# 33.63       -114.58                29.0       1387.0           236.0
# 34.83       -114.60                46.0       1497.0           309.0
# 34.84       -114.61                48.0       1291.0           248.0
#
#           population  households  median_income  median_house_value
# latitude
# 33.64          515.0       226.0         3.1917             73400.0
# 33.57          624.0       262.0         1.9250             65500.0
# 33.63          671.0       239.0         3.3438             74000.0
# 34.83          787.0       271.0         2.1908             48100.0
# 34.84          580.0       211.0         2.1571             48600.0

# %%
# setting values using loc
california_df.loc[california_df['median_income'].between(0,1)] = 0

# %%
california_df.loc[(california_df.median_income > 2) & (california_df.population>1000), 'median_house_value'] = 100000

# %%
'''Using iloc for indexing/selecting records using pandas. iloc uses integer-location based indexing unlike loc which uses
label based indexing'''

california_df.iloc[0].head()  # selecting the first row ; Note: returns a series
california_df.iloc[1].head()  # selecting the second row 
california_df.iloc[-1].head() # selecting the last row
# Out:
# longitude             -124.35
# housing_median_age      52.00
# total_rooms           1820.00
# total_bedrooms         300.00
# population             806.00
# Name: 40.54, dtype: float64

# %%
# selecting columns\
california_df.iloc[:,0].head() # first column of data frame 
california_df.iloc[:,1].head() # second column of data frame
california_df.iloc[:,-1].head() # last column of data frame
# Out:
# latitude
# 34.19    66900.0
# 34.40    80100.0
# 33.69    85700.0
# 33.64    73400.0
# 33.57    65500.0
# Name: median_house_value, dtype: float64

# %%
# selecting multiple columns and rows together
california_df.iloc[0:5].head() # first five rows of dataframe
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.19       -114.31                15.0       5612.0          1283.0
# 34.40       -114.47                19.0       7650.0          1901.0
# 33.69       -114.56                17.0        720.0           174.0
# 33.64       -114.57                14.0       1501.0           337.0
# 33.57       -114.57                20.0       1454.0           326.0
#
#           population  households  median_income  median_house_value
# latitude
# 34.19         1015.0       472.0         1.4936             66900.0
# 34.40         1129.0       463.0         1.8200             80100.0
# 33.69          333.0       117.0         1.6509             85700.0
# 33.64          515.0       226.0         3.1917             73400.0
# 33.57          624.0       262.0         1.9250             65500.0

# %%
# first two columns of data frame with all rows
california_df.iloc[:, 0:2].head()
# Out:
#           longitude  housing_median_age
# latitude
# 34.19       -114.31                15.0
# 34.40       -114.47                19.0
# 33.69       -114.56                17.0
# 33.64       -114.57                14.0
# 33.57       -114.57                20.0

# %%
# 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
california_df.iloc[[0,3,6,24], [0,5,6]].head()
# Out:
#           longitude  households  median_income
# latitude
# 34.19       -114.31       472.0         1.4936
# 33.64       -114.57       226.0         3.1917
# 33.61       -114.58       633.0         2.6768
# 33.54       -115.22       283.0         1.6250

# %%
## first 5 rows and 5th, 6th, 7th columns of data frame
california_df.iloc[0:5, 5:8]
# Out:
#           households  median_income  median_house_value
# latitude
# 34.19          472.0         1.4936             66900.0
# 34.40          463.0         1.8200             80100.0
# 33.69          117.0         1.6509             85700.0
# 33.64          226.0         3.1917             73400.0
# 33.57          262.0         1.9250             65500.0

# %% [markdown]
# ### The below image can summarize the syntax for loc and iloc methods

# %% [markdown]
# <img src="Pandas-selections-and-indexing.png">

# %% [markdown]
# #### For more examples you can check out following links
# https://pandas.pydata.org/pandas-docs/stable/10min.html
# https://pandas.pydata.org/pandas-docs/stable/cookbook.html
